# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel("41467_2021_23713_MOESM4_ESM.xlsx", sheet_name = "Identifications")
df
# Out:
#                       Sequence  Average Retention Time  Average iRT  \
# 0       AAAAAAAAAAAAAAAAGLGLGP                   59.86       157.46
# 1              AAAAAAAAAAAAAAG                   32.74        56.27
# 2            AAAAAAAAAAAAAAGAG                   36.89        70.22
# 3       AAAAAAAAAAAAAAGGLALGLH                   55.88       144.30
# 4          AAAAAAAAAAAAAAVTSGV                   52.37         0.00
# ...                        ...                     ...          ...
# 267256              YYYRPLYDAY                   37.51        82.51
# 267257               YYYTKEEQF                   28.50        47.96
# 267258               YYYTVTPSY                   36.44        81.43
# 267259               YYYVGFAYL                   56.25       156.45
# 267260                YYYYIREA                   32.48        61.59
#
#         Max Score FTMS_HCD_20  Max Score FTMS_HCD_23  Max Score FTMS_HCD_25  \
# ...

# %%
plt.scatter(range(len(df["Average iRT"])), sorted(df["Average iRT"]), s=1)
